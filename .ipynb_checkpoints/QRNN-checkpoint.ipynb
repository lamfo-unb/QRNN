# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from QRNN import QRNN

from matplotlib import pyplot as plt
plt.style.use("ggplot")

# %%
data  = pd.read_csv('SP500.csv', usecols=['Adjusted Close', 'Date'])
data = data.iloc[::-1]
print(data.shape)
data.head()
# Out:
# (16805, 2)
#              Date  Adjusted Close
# 16804  1950-01-03           16.66
# 16803  1950-01-04           16.85
# 16802  1950-01-05           16.93
# 16801  1950-01-06           16.98
# 16800  1950-01-09           17.08

# %%
model = QRNN(timesteps=15, tau=.05, lr=0.005, neurons=100, iterations=1000)

# %%
X_train, y_train, X_test, y_test = model.train_test_split(data[["Adjusted Close"]], n_test=500)

# %%
model.train(X_train, y_train)
# Out:
# 0 	Custo de treinamento: 0.551853
# 1000 	Custo de treinamento: 0.303807

# %%
print('\nTreino:')
model.score(X_train, y_train)

print('\nTeste:')
model.score(X_test, y_test)
# Out:
# Treino:
# INFO:tensorflow:Restoring parameters from ./tmp/QRNN.ckpt
# #Hits:  0.0534191965655
# Quantile Loss:  0.103505373583
#
# Teste:
# INFO:tensorflow:Restoring parameters from ./tmp/QRNN.ckpt
# #Hits:  0.056
# Quantile Loss:  0.09233304886

# %%
var_train_mean, var_train_var = model.predict(X_train)
var_test_mean, var_test_var = model.predict(X_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./tmp/QRNN.ckpt
# INFO:tensorflow:Restoring parameters from ./tmp/QRNN.ckpt

# %%
train_data = data[:X_train.shape[0]]
train_data["Return"] = y_train[:, 0, 0] 
train_data["VaR"] = var_train_mean
train_data["VaR_std"] = np.sqrt(var_train_var)

valid_data = data[X_train.shape[0]:]
valid_data["Return"] = y_test[:, 0, 0] 
valid_data["VaR"] = var_test_mean
valid_data["VaR_std"] = np.sqrt(var_test_var)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
fig = plt.figure(figsize=(20,10))
plt.plot(pd.to_datetime(train_data['Date']), train_data['Return'])
plt.plot(pd.to_datetime(train_data['Date']), train_data['VaR'])
plt.show()

# %%
t = range(len(valid_data['Date']))

fig = plt.figure(figsize=(20,10))
plt.plot(t, valid_data['Return'])
plt.plot(t, valid_data['VaR'])

for shade in range(1, 5):
    plt.fill_between(t,
                     valid_data['VaR'].values.reshape(-1)+valid_data['VaR_std'].values.reshape(-1),
                     valid_data['VaR'].values.reshape(-1)-valid_data['VaR_std'].values.reshape(-1) * (.5*shade),
                     alpha=0.2, color="C2") # 90% IC

plt.show()
